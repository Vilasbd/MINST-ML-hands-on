# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
X, y = mnist["data"], mnist["target"]
X.shape
# Out:
# (70000, 784)

# %%
 y.shape
# Out:
# (70000,)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Example DataFrame with 784 columns (28x28 images flattened)
data = np.random.rand(5, 784)  # 5 rows, 784 columns
df = pd.DataFrame(data)

# Accessing the first row
some_digit = df.iloc[0].values  # Convert row to NumPy array

# Reshape the 1D array to a 2D array (28x28) for plotting
some_digit_image = some_digit.reshape(28, 28)

# Plotting the image
plt.imshow(some_digit_image, cmap="binary")
plt.axis("off")  # Hide the axis
plt.show()

# %%
y[0]
# Out:
# '5'

# %%
 y = y.astype(np.uint8)

# %%
X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000],y[60000:]

# %%
y_train_5 = (y_train == 5)
y_test_5 = (y_test == 5)

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train_5)
# Out:
# SGDClassifier(random_state=42)

# %%
sgd_clf.predict([some_digit])
# Out:
# C:\Users\VILAS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SGDClassifier was fitted with feature names
#   warnings.warn(
# array([False])

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(sgd_clf, X_train, y_train_5, cv=3,scoring="accuracy")
# Out:
# array([0.95035, 0.96035, 0.9604 ])
